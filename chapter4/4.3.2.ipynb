# %%
import pandas as pd
import numpy as np

amex_df = pd.read_csv('./gen/amex_df.csv',
                           parse_dates=True,
                           index_col=0)
amex_df.tail()


bins = [-np.inf,
        -7.0,
        -5,
        -3,
        0,
        3,
        5,
        7,
        np.inf]
fixed_cuts = pd.cut(amex_df.p_change, bins)
change_ration_dummies = pd.get_dummies(fixed_cuts,
                                       prefix='cr_dummies')

# %%
pd.concat([amex_df, change_ration_dummies], axis=1).tail()
# Out:
#             close   high    low  p_change   open  pre_close   volume  \
# 2018-12-24  89.50  91.55  89.50    -2.004  90.74      91.33  3190855
# 2018-12-26  93.84  93.89  89.05     4.849  89.85      89.50  5383666
# 2018-12-27  93.84  93.89  89.05     0.000  89.85      93.84  5383666
# 2018-12-28  93.84  93.89  89.05     0.000  89.85      93.84  5383666
# 2018-12-31  93.84  93.89  89.05     0.000  89.85      93.84  5383666
#
#                 date  date_week  key     atr21     atr14  \
# 2018-12-24  20181224          0  392  4.443110  4.863392
# 2018-12-26  20181226          2  393  4.479191  4.860273
# 2018-12-27  20181227          3  394  4.511992  4.857570
# 2018-12-28  20181228          4  395  4.541811  4.855227
# 2018-12-31  20181231          0  396  4.568919  4.853197
#
#             cr_dummies_(-inf, -7.0]  cr_dummies_(-7.0, -5.0]  \
# 2018-12-24                        0                        0
# 2018-12-26                        0                        0
# ...

# %%
pd.concat([amex_df[amex_df.p_change > 2],
           amex_df[amex_df.atr14 > 3]],
          axis=0)
# Out:
#              close     high     low  p_change    open  pre_close    volume  \
# 2017-10-26   95.69   95.730   93.98     2.309   93.99     93.530   4136780
# 2018-02-06   94.18   94.220   88.51     2.358   89.75     92.010   7243978
# 2018-02-09   91.72   92.520   87.54     3.826   89.47     88.340   8017551
# 2018-02-12   95.14   95.620   92.42     3.729   92.54     91.720    348678
# 2018-02-26  101.64  101.675   98.97     2.874   99.43     98.800   4953120
# 2018-03-09   99.05   99.110   97.06     2.547   97.58     96.590   3044292
# 2018-03-26   92.62   92.990   90.80     2.399   91.37     90.450   2769845
# 2018-04-18   98.28   95.220   94.08     4.626   94.08     93.935    435538
# 2018-04-19  102.37  102.960   99.05     4.162   99.36     98.280  11716884
# 2018-10-19  106.73  107.550  104.06     3.783  104.06    102.840   5726327
# 2018-11-26  109.68  109.730  106.83     3.726  107.15    105.740   4488477
# ...

# %%
amex_df[amex_df.p_change > 2].append(amex_df[amex_df.atr14 > 3])

# %%
stock_a = pd.DataFrame({
    'stock_a': [
        'a', 'b', 'c', 'd', 'a'
    ],
    'data': range(5)
})
stock_b = pd.DataFrame({
    'stock_b': [
        'a', 'b', 'c'
    ],
    'data2': range(3)
})
pd.merge(stock_a, 
         stock_b,
         left_on='stock_a',
         right_on='stock_b')
# Out:
#   stock_a  data stock_b  data2
# 0       a     0       a      0
# 1       a     4       a      0
# 2       b     1       b      1
# 3       c     2       c      2
